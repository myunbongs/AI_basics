# %%
import numpy as np
import numpy.linalg as npl # numpy에서 제공하는 선형대수학 
import matplotlib.pyplot as plt
import PIL
from PIL import Image

# %%
plt.rcParams[ "figure.figsize" ] = (10,10)
origin2D = np.array([0,0]) # 2차원일 때 원점
origin3D = np.array([0,0,0]) # 3차원일 때 원점 
scale = 10

# %% [markdown]
# ## (행) 벡터, 열벡터

# %%
print(np.array([1,0]))
print(np.hstack([1,0])) # horizontal로 stack해라! 
print(np.vstack([1,0])) # column vector
# Out:
# [1 0]
# [1 0]
# [[1]
#  [0]]

# %% [markdown]
# # 4.4.1 Determinant: 면적(2D)/부피(3D 이상)
# 1) The area(volume) of the parallelogram spanned by the vectors b** and **g is |det(b,g)|

# %%
g = np.vstack([1,0])
b = np.vstack([0,1])


#determinant 계산

# 1) g,b를 열벡터로 갖는 matrix A 선언
A = np.hstack([g,b]) # [g vector b vector]
print("A:")
print(A)

# 2) matrix A의 determinant 계산
print("det(A):")
print(npl.det(A))
# Out:
# A:
# [[1 0]
#  [0 1]]
# det(A):
# 1.0

# %%
# 화살표 그리기: 원점(x, y), 방향(u, v)
plt.axis([-scale/2, scale/2, -scale/2, scale/2]) # 축 정해주기 위에서 scale=10으로 설정

plt.quiver(origin2D[0], origin2D[1], g[0], g[1], scale = scale, color = "g") # (start point, end point) start point와 end point를 잇는 vector 그리기
plt.quiver(origin2D[0], origin2D[1], b[0], b[1], scale = scale, color = "b")
plt.quiver(g[0], g[1], b[0], b[1], scale = scale, width = 0.005, color = "b")
plt.quiver(b[0], b[1], g[0], g[1], scale = scale, width = 0.005, color = "g")

plt.show()

# %% [markdown]
# 2) The volume of the paralellepiped spanned by the vectors r, b, g is |det([r,b,g])|.

# %%
# 3차원 
r = np.vstack([2, 0, -8])
g = np.vstack([6, 1, 0])
b = np.vstack([1, 4, -1])
A = np.hstack([r, g, b])
print("A :")
print(A)

print("det(A):")
print(npl.det(A))
# Out:
# A :
# [[ 2  6  1]
#  [ 0  1  4]
#  [-8  0 -1]]
# det(A):
# -185.99999999999991

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline

fig = plt.figure()
ax = plt.axes(projection="3d") 
scale3D = 15
ax.set_xlim3d(-scale3D, scale3D)
ax.set_ylim3d(scale3D, -scale3D)
ax.set_zlim3d(-scale3D, scale3D)
ax.grid(b=None)

# determinant 그리기
# start point부터 vector(end point)까지 그려라
ax.quiver(origin3D[0], origin3D[1], origin3D[2], # start point 
          A[0,0], A[1,0], A[2,0], # end point
         color = "r", linewidths = .5, arrow_length_ratio = .05) 
ax.quiver(origin3D[0], origin3D[1], origin3D[2], # start point 
          A[0,1], A[1,1], A[2,1], # end point 
         color = "g", linewidths = .5, arrow_length_ratio = .05) 
ax.quiver(origin3D[0], origin3D[1], origin3D[2], # start point
          A[0,2], A[1,2], A[2,2], # end point
         color = "b", linewidths = .5, arrow_length_ratio = .05)

import itertools as it

quiverkey = dict(linewidths = .5, arrow_length_ratio = .05, label="_nolegend_")
c = ["r", "g", "b"]

for i in [ i for i in list(it.product([0,1,2],repeat=2)) if i[0]!=i[1]]:
    ax.quiver(A[0,i[0]], A[1,i[0]], A[2,i[0]],
             A[0,i[1]], A[1,i[1]], A[2,i[1]],
             color = c[i[1]], **quiverkey)
    
ax.quiver(A[0,1]+A[0,2], A[1,1]+A[1,2], A[2,1]+A[2,2],
         A[0,0], A[1,0], A[2,0],
         color = "r", **quiverkey)
ax.quiver(A[0,2]+A[0,0], A[1,2]+A[1,0], A[2,2]+A[2,0],
         A[0,1], A[1,1], A[2,1],
         color = "g", **quiverkey)
ax.quiver(A[0,0]+A[0,1], A[1,0]+A[1,1], A[2,0]+A[2,1],
         A[0,2], A[1,2], A[2,2],
         color = "b", **quiverkey)

plt.show()

# %% [markdown]
# ## 4.1.3 Trace

# %%
# hstack으로도 구현 가능 
A = np.array([[3, 4, -8],
            [1, 3, 7],
            [6, -11, 2]])
print("A :")
print(A)

print("Trace(A):")
print(np.trace(A))
# Out:
# A :
# [[  3   4  -8]
#  [  1   3   7]
#  [  6 -11   2]]
# Trace(A):
# 8

# %%
# x^T와 y를 inner product = x와 y^T를 outer product의 trace
x = np.vstack([3, -1])
y = np.vstack([8, 5])
print("tr(xy^T) :") 
yt = np.transpose(y)
print(np.trace( x.dot(yt) ))

print("x^Ty :")
xt = np.transpose(x)
print(xt.dot(y))
# Out:
# tr(xy^T) :
# 19
# x^Ty :
# [[19]]

# %% [markdown]
# ## 4.2 Cholesky decomposition
# A = LL^T

# %%
A = np.vstack([[3,2,2], [2,3,2], [2,2,3]])
print("A :")
print(A)

print("Cholesky(A): L")
print(npl.cholesky(A))

print("L^T")
print(np.transpose( npl.cholesky(A) ))
# Out:
# A :
# [[3 2 2]
#  [2 3 2]
#  [2 2 3]]
# Cholesky(A): L
# [[1.73205081 0.         0.        ]
#  [1.15470054 1.29099445 0.        ]
#  [1.15470054 0.51639778 1.18321596]]
# L^T
# [[1.73205081 1.15470054 1.15470054]
#  [0.         1.29099445 0.51639778]
#  [0.         0.         1.18321596]]

# %% [markdown]
# ## 4.3 Eigendecomposition
# 1) eigen values & eigen vectors of A
# Au = 감마u

# %%
A = np.vstack([[4,2], [1,3]])
print("A :")
print(A)

e_values, e_vectors = npl.eig(A)
print(e_values)
print(e_vectors)

#eigen vector u1, u1
u1 = np.vstack(e_vectors[:, 0])
u2 = np.vstack(e_vectors[:, 1])
print("u1 : ", u1)
print("u2 : ", u2)

# eigen value lambda1, lambda2
l1, l2 = e_values[0], e_values[1]
print("eigen values: ", l1, l2)

# check
print("Au1 : ", np.dot(A, u1))
print("l1*u1: ", l1*u1)

print("Au2 : ", np.dot(A, u1))
print("l2*u2: ", l2*u2)
# Out:
# A :
# [[4 2]
#  [1 3]]
# [5. 2.]
# [[ 0.89442719 -0.70710678]
#  [ 0.4472136   0.70710678]]
# ('u1 : ', array([[0.89442719],
#        [0.4472136 ]]))
# ('u2 : ', array([[-0.70710678],
#        [ 0.70710678]]))
# ('eigen values: ', 5.0, 2.0)
# ('Au1 : ', array([[4.47213595],
#        [2.23606798]]))
# ('l1*u1: ', array([[4.47213595],
#        [2.23606798]]))
# ('Au2 : ', array([[4.47213595],
#        [2.23606798]]))
# ('l2*u2: ', array([[-1.41421356],
#        [ 1.41421356]]))

# %% [markdown]
# # 4.4 Singular value decomposition (SVD)
#
# ## 1) Stonhenge 이미지 파일 파악

# %%
stonehenge = Image.open('stonehenge.png')
print(stonehenge)
print(stonehenge.format)
print(stonehenge.size)
print(stonehenge.mode)

plt.imshow(stonehenge)
plt.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=960x635 at 0x7FB2E16E7610>
# PNG
# (960, 635)
# RGBA

# %% [markdown]
# ### 2) 픽셀값 0~1 사이로 만들기

# %%
imMatrix = np.array(stonehenge.convert("L"))/255.0
print( imMatrix.shape )
print( imMatrix )
# Out:
# (635, 960)
# [[0.35294118 0.34509804 0.3372549  ... 0.48627451 0.46666667 0.48627451]
#  [0.32156863 0.32941176 0.31372549 ... 0.47843137 0.45098039 0.4627451 ]
#  [0.34117647 0.37647059 0.34117647 ... 0.49019608 0.47058824 0.47058824]
#  ...
#  [0.41568627 0.41568627 0.41960784 ... 0.39215686 0.39215686 0.4       ]
#  [0.42352941 0.43137255 0.42745098 ... 0.38431373 0.39607843 0.4       ]
#  [0.43137255 0.45098039 0.42745098 ... 0.37254902 0.39607843 0.39607843]]

# %% [markdown]
# ### 3) SVD 수행

# %%
scalar = 1/2
shape = np.shape(imMatrix)
U,S,V = npl.svd(imMatrix)
Sd = np.hstack([np.eye(shape[0])*S.copy(), np.zeros((shape[0], shape[1]-shape[0]))])
print(np.shape(U), np.shape(Sd), np.shape(V))

# --- image reconstruction with the SVD --- 
#  usv = U @ Sd @ V
# U x Sd x V
np.matmul( np.matmul( U, Sd ), V )
usv = U.dot(Sd).dot(V)
print( np.allclose( imMatrix, usv ) )

# check 2. U x Sd x V 그려보기
plt.imshow(usv, cmap='gray')    
plt.show()
# Out:
# ((635, 635), (635, 960), (960, 960))
# True

# %% [markdown]
# ### 4) Ai 시각화

# %%
k = 1
print(np.shape(U[:, :k]))
print(np.shape(np.diag(S[:k])))
print(np.shape(V.T[:, :k].T))

m, n = np.shape(imMatrix)
partial, total = k * ( m + n ) + k, m * n
print( np.ndim(imMatrix), [np.shape(i) for i in [imMatrix, U, Sd, V]])
print(partial, total, partial/total)

size = ( 200, 200 )
# np.matmul( np.matmul( U, Sd ), V )
# imtemp = lambda k: (np.vstack(U[:,k-1])@np.vstack([S[k-1]])@np.vstack(V[k-1]).T)*255
imtemp = lambda k: np.matmul ( np.matmul ( np.vstack(U[:,k-1]), np.vstack([S[k-1]])), np.vstack(V[k-1]).T ) * 255

for i in list(range( 1, 6)):
    im = Image.fromarray(imtemp(i).astype('uint8'))
    im.thumbnail( size, Image.ANTIALIAS)
    plt.imshow( im, cmap='gray')
    plt.show()
# Out:
# (635, 1)
# (1, 1)
# (1, 960)
# (2, [(635, 960), (635, 635), (635, 960), (960, 960)])
# (1596, 609600, 0)

# %% [markdown]
# ### 5) A^(i) 시각화

# %%
quality = 5
np.shape(np.diag(S[:quality]))
np.shape(U[:,:quality])
np.shape(V[:quality,:])
k = quality
m, n = np.shape(imMatrix)
partial, total = k * ( m + n ) + k, m * n
np.ndim(imMatrix), [np.shape(i) for i in [imMatrix, U, Sd, V]]
partial, total, partial/total

# imtemp = lambda k: (U[:,:k]@np.diag(S[:k])@V.T[:, :k].T)*255
imtemp = lambda k: np.matmul ( np.matmul ( U[:,:k], np.diag(S[:k])), V.T[:, :k].T) * 255

for i in list(range(1, k+1)):
    im = Image.fromarray(imtemp(i).astype('uint8'))
    im.thumbnail(size, Image.ANTIALIAS)
    plt.imshow(im, cmap='gray')
    plt.show()

# %% [markdown]
# ### 6) Rank-k A^(i) 시각화

# %%
k = 30
im = imtemp(k)

m, n = np.shape(imMatrix)
partial, total = (k*(m+n)+k, m*n)
partial, total, partial/total

plt.imshow(im, cmap='gray')
plt.show()
